# %%
import os
import sys
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import pickle
from tensorflow import keras 
warnings.filterwarnings("ignore")
from sklearn.model_selection import train_test_split
from tensorflow.python.keras.layers import Conv1D

# %%
sys.path.append(os.path.join(os.path.dirname(os.path.dirname(os.getcwd())),'python-packages/'))
from deep_hashing_models import *
from similarities import *
from lsh_search import *

# %% [markdown]
# # 1. Data Preparation

# %%
data_repo = os.path.join(os.path.dirname(os.path.dirname(os.path.dirname(os.getcwd()))),'data/')

# %%
df_distinct_stacks = pd.read_csv(data_repo + 'frequent_stack_traces.csv', index_col = [0])
df_measures = pd.read_csv(data_repo + 'similarity-measures-pairs.csv', index_col = [0])

# %%
n_stacks = df_distinct_stacks.shape[0]
n_stacks
# Out:
# 1000

# %%
df_distinct_stacks['listStackTrace'] = df_distinct_stacks['stackTraceCusto'].apply(lambda x : x.split('\n'))
corpus = df_distinct_stacks['listStackTrace'].tolist()
frames = pd.Series(list(set([elt for l in corpus for elt in l])))
df_frames = pd.DataFrame()
df_frames['frame'] = pd.get_dummies(frames).T.reset_index().rename(columns={'index': 'frame'})['frame']
df_frames['embedding'] = pd.get_dummies(frames).T.reset_index().apply(lambda x : x[1:].values, axis = 1)
df_distinct_stacks['rankFrames'] = df_distinct_stacks['listStackTrace'].apply(lambda x : index_frame(x, df_frames))

# %%
df_brodie = pd.DataFrame()
df_brodie['Brodie'] = df_measures['Brodie']
df_brodie['stack1'] = df_brodie.apply(lambda x : assign_stacks(rowIndex(x), df_distinct_stacks)[0], axis = 1)
df_brodie['stack2'] = df_brodie.apply(lambda x : assign_stacks(rowIndex(x), df_distinct_stacks)[1], axis = 1)

# %%
embeddings = 1 * np.random.randn(df_frames.shape[0] + 1, df_frames['embedding'][0].shape[0])
embeddings[0] = 0
embeddings[1:] = np.vstack(df_frames['embedding'].tolist())
embeddings.shape
# Out:
# (2251, 2250)

# %%
X = df_brodie[['stack1','stack2']]
Y = df_brodie['Brodie']
X_train, X_validation, Y_train, Y_validation = train_test_split(X, Y, test_size = 0.2)

max_length = df_distinct_stacks['listStackTrace'].apply(lambda x : len(x)).max()
X_train = padding(X_train, max_length)
X_validation = padding(X_validation, max_length)

# %%
Y_train = Y_train.values
Y_validation = Y_validation.values

# %%
assert X_train['stack_1'].shape == X_train['stack_2'].shape
assert len(X_train['stack_1']) == len(Y_train)

# %% [markdown]
# ### Distribution of training data

# %%
plt.rcParams["figure.figsize"] = [10, 5]
plt.hist(Y_train, 20, alpha = 1, density = False)
plt.show()

# %% [markdown]
# ### Distribution of test data

# %%
plt.rcParams["figure.figsize"] = [10, 5]
plt.hist(Y_validation, 20, alpha = 1, density = False)
plt.show()

# %% [markdown]
# # 2. Model Design

# %%
'Number of hash tables functions' 
m = 64

# %%
'Number of bits per hash function' 
b = 16

# %%
'Size hash vector'
size_hash_vector = m * b
size_hash_vector
# Out:
# 1024

# %% [markdown]
# ## 2.1. Feature learning phase

# %%
input_tensor = Input(shape = (max_length,))
input_layer = (Embedding(len(embeddings), df_frames.shape[0], weights=[embeddings], input_shape=(max_length,), trainable=False))(input_tensor)
submodels = []
for kw in (3,4) :
    conv_layer = Conv1D(1024, kw, activation='tanh')(input_layer)
    maxpool_layer = GlobalMaxPooling1D()(conv_layer)
    submodels.append(maxpool_layer)
conc_layer = concatenate(submodels, axis=1)
dense_layer = Dense(size_hash_vector, activation = 'tanh')(conc_layer)
x = Sequential()
x.add(Model(inputs = input_tensor, outputs = dense_layer))
shared_model = x

# %% [markdown]
# ## 2.2. Siamese Model

# %%
input_shape = (max_length,)
model = siamese_model_baseline(shared_model, input_shape, is_sparse = False, print_summary = False)

# %% [markdown]
# ## 2.3. Model training

# %%
siamese_model = train_siamese_model_baseline(model, X_train, X_validation, Y_train, Y_validation, size_hash_vector, batch_size = 512, epochs = 20)
# Out:
# Epoch 1/20
# 781/781 [==============================] - 301s 378ms/step - loss: -0.4624 - manh_dist_loss: 0.0593 - abs_vect_loss: -0.9842 - abs_vect_1_loss: -0.9841 - manh_dist_rmse: 0.2434 - manh_dist_mae: 0.1815 - val_loss: -0.4772 - val_manh_dist_loss: 0.0328 - val_abs_vect_loss: -0.9873 - val_abs_vect_1_loss: -0.9870 - val_manh_dist_rmse: 0.1812 - val_manh_dist_mae: 0.1430
# Epoch 2/20
# 781/781 [==============================] - 295s 377ms/step - loss: -0.4786 - manh_dist_loss: 0.0303 - abs_vect_loss: -0.9876 - abs_vect_1_loss: -0.9876 - manh_dist_rmse: 0.1742 - manh_dist_mae: 0.1393 - val_loss: -0.4793 - val_manh_dist_loss: 0.0278 - val_abs_vect_loss: -0.9865 - val_abs_vect_1_loss: -0.9864 - val_manh_dist_rmse: 0.1667 - val_manh_dist_mae: 0.1337
# Epoch 3/20
# 781/781 [==============================] - 295s 378ms/step - loss: -0.4799 - manh_dist_loss: 0.0280 - abs_vect_loss: -0.9879 - abs_vect_1_loss: -0.9879 - manh_dist_rmse: 0.1674 - manh_dist_mae: 0.1354 - val_loss: -0.4799 - val_manh_dist_loss: 0.0276 - val_abs_vect_loss: -0.9874 - val_abs_vect_1_loss: -0.9875 - val_manh_dist_rmse: 0.1660 - val_manh_dist_mae: 0.1342
# Epoch 4/20
# 781/781 [==============================] - 294s 377ms/step - loss: -0.4804 - manh_dist_loss: 0.0272 - abs_vect_loss: -0.9880 - abs_vect_1_loss: -0.9881 - manh_dist_rmse: 0.1651 - manh_dist_mae: 0.1340 - val_loss: -0.4806 - val_manh_dist_loss: 0.0272 - val_abs_vect_loss: -0.9882 - val_abs_vect_1_loss: -0.9884 - val_manh_dist_rmse: 0.1648 - val_manh_dist_mae: 0.1332
# Epoch 5/20
# 781/781 [==============================] - 294s 376ms/step - loss: -0.4807 - manh_dist_loss: 0.0269 - abs_vect_loss: -0.9881 - abs_vect_1_loss: -0.9882 - manh_dist_rmse: 0.1639 - manh_dist_mae: 0.1330 - val_loss: -0.4805 - val_manh_dist_loss: 0.0261 - val_abs_vect_loss: -0.9870 - val_abs_vect_1_loss: -0.9870 - val_manh_dist_rmse: 0.1614 - val_manh_dist_mae: 0.1305
# Epoch 6/20
# 781/781 [==============================] - 293s 375ms/step - loss: -0.4808 - manh_dist_loss: 0.0266 - abs_vect_loss: -0.9882 - abs_vect_1_loss: -0.9883 - manh_dist_rmse: 0.1632 - manh_dist_mae: 0.1322 - val_loss: -0.4800 - val_manh_dist_loss: 0.0281 - val_abs_vect_loss: -0.9879 - val_abs_vect_1_loss: -0.9883 - val_manh_dist_rmse: 0.1677 - val_manh_dist_mae: 0.1366
# Epoch 7/20
# 781/781 [==============================] - 293s 376ms/step - loss: -0.4808 - manh_dist_loss: 0.0265 - abs_vect_loss: -0.9882 - abs_vect_1_loss: -0.9882 - manh_dist_rmse: 0.1629 - manh_dist_mae: 0.1326 - val_loss: -0.4807 - val_manh_dist_loss: 0.0267 - val_abs_vect_loss: -0.9882 - val_abs_vect_1_loss: -0.9878 - val_manh_dist_rmse: 0.1633 - val_manh_dist_mae: 0.1327
# Epoch 8/20
# 781/781 [==============================] - 293s 375ms/step - loss: -0.4811 - manh_dist_loss: 0.0262 - abs_vect_loss: -0.9884 - abs_vect_1_loss: -0.9884 - manh_dist_rmse: 0.1619 - manh_dist_mae: 0.1315 - val_loss: -0.4809 - val_manh_dist_loss: 0.0267 - val_abs_vect_loss: -0.9884 - val_abs_vect_1_loss: -0.9885 - val_manh_dist_rmse: 0.1634 - val_manh_dist_mae: 0.1322
# Epoch 9/20
# 781/781 [==============================] - 293s 376ms/step - loss: -0.4812 - manh_dist_loss: 0.0262 - abs_vect_loss: -0.9885 - abs_vect_1_loss: -0.9886 - manh_dist_rmse: 0.1619 - manh_dist_mae: 0.1314 - val_loss: -0.4803 - val_manh_dist_loss: 0.0300 - val_abs_vect_loss: -0.9906 - val_abs_vect_1_loss: -0.9905 - val_manh_dist_rmse: 0.1733 - val_manh_dist_mae: 0.1417
# Epoch 10/20
# 781/781 [==============================] - 293s 375ms/step - loss: -0.4812 - manh_dist_loss: 0.0262 - abs_vect_loss: -0.9886 - abs_vect_1_loss: -0.9886 - manh_dist_rmse: 0.1619 - manh_dist_mae: 0.1312 - val_loss: -0.4810 - val_manh_dist_loss: 0.0261 - val_abs_vect_loss: -0.9882 - val_abs_vect_1_loss: -0.9883 - val_manh_dist_rmse: 0.1617 - val_manh_dist_mae: 0.1308
# Epoch 11/20
# 781/781 [==============================] - 294s 376ms/step - loss: -0.4814 - manh_dist_loss: 0.0260 - abs_vect_loss: -0.9888 - abs_vect_1_loss: -0.9888 - manh_dist_rmse: 0.1613 - manh_dist_mae: 0.1307 - val_loss: -0.4811 - val_manh_dist_loss: 0.0259 - val_abs_vect_loss: -0.9880 - val_abs_vect_1_loss: -0.9883 - val_manh_dist_rmse: 0.1610 - val_manh_dist_mae: 0.1305
# Epoch 12/20
# 781/781 [==============================] - 293s 376ms/step - loss: -0.4816 - manh_dist_loss: 0.0258 - abs_vect_loss: -0.9889 - abs_vect_1_loss: -0.9890 - manh_dist_rmse: 0.1606 - manh_dist_mae: 0.1301 - val_loss: -0.4811 - val_manh_dist_loss: 0.0253 - val_abs_vect_loss: -0.9877 - val_abs_vect_1_loss: -0.9874 - val_manh_dist_rmse: 0.1589 - val_manh_dist_mae: 0.1283
# Epoch 13/20
# 781/781 [==============================] - 295s 378ms/step - loss: -0.4816 - manh_dist_loss: 0.0258 - abs_vect_loss: -0.9890 - abs_vect_1_loss: -0.9891 - manh_dist_rmse: 0.1605 - manh_dist_mae: 0.1299 - val_loss: -0.4811 - val_manh_dist_loss: 0.0270 - val_abs_vect_loss: -0.9892 - val_abs_vect_1_loss: -0.9894 - val_manh_dist_rmse: 0.1644 - val_manh_dist_mae: 0.1320
# Epoch 14/20
# 781/781 [==============================] - 295s 378ms/step - loss: -0.4817 - manh_dist_loss: 0.0257 - abs_vect_loss: -0.9890 - abs_vect_1_loss: -0.9892 - manh_dist_rmse: 0.1604 - manh_dist_mae: 0.1297 - val_loss: -0.4810 - val_manh_dist_loss: 0.0282 - val_abs_vect_loss: -0.9902 - val_abs_vect_1_loss: -0.9903 - val_manh_dist_rmse: 0.1680 - val_manh_dist_mae: 0.1363
# Epoch 15/20
# 781/781 [==============================] - 294s 377ms/step - loss: -0.4817 - manh_dist_loss: 0.0257 - abs_vect_loss: -0.9890 - abs_vect_1_loss: -0.9892 - manh_dist_rmse: 0.1604 - manh_dist_mae: 0.1299 - val_loss: -0.4813 - val_manh_dist_loss: 0.0267 - val_abs_vect_loss: -0.9892 - val_abs_vect_1_loss: -0.9892 - val_manh_dist_rmse: 0.1634 - val_manh_dist_mae: 0.1320
# Epoch 16/20
# 781/781 [==============================] - 294s 376ms/step - loss: -0.4817 - manh_dist_loss: 0.0257 - abs_vect_loss: -0.9891 - abs_vect_1_loss: -0.9893 - manh_dist_rmse: 0.1604 - manh_dist_mae: 0.1296 - val_loss: -0.4811 - val_manh_dist_loss: 0.0259 - val_abs_vect_loss: -0.9881 - val_abs_vect_1_loss: -0.9881 - val_manh_dist_rmse: 0.1608 - val_manh_dist_mae: 0.1301
# Epoch 17/20
# 781/781 [==============================] - 294s 377ms/step - loss: -0.4818 - manh_dist_loss: 0.0257 - abs_vect_loss: -0.9891 - abs_vect_1_loss: -0.9893 - manh_dist_rmse: 0.1603 - manh_dist_mae: 0.1296 - val_loss: -0.4812 - val_manh_dist_loss: 0.0279 - val_abs_vect_loss: -0.9903 - val_abs_vect_1_loss: -0.9904 - val_manh_dist_rmse: 0.1670 - val_manh_dist_mae: 0.1347
# Epoch 18/20
# 781/781 [==============================] - 300s 384ms/step - loss: -0.4818 - manh_dist_loss: 0.0257 - abs_vect_loss: -0.9892 - abs_vect_1_loss: -0.9893 - manh_dist_rmse: 0.1602 - manh_dist_mae: 0.1295 - val_loss: -0.4813 - val_manh_dist_loss: 0.0263 - val_abs_vect_loss: -0.9888 - val_abs_vect_1_loss: -0.9888 - val_manh_dist_rmse: 0.1621 - val_manh_dist_mae: 0.1306
# Epoch 19/20
# 781/781 [==============================] - 325s 416ms/step - loss: -0.4819 - manh_dist_loss: 0.0256 - abs_vect_loss: -0.9893 - abs_vect_1_loss: -0.9895 - manh_dist_rmse: 0.1599 - manh_dist_mae: 0.1292 - val_loss: -0.4815 - val_manh_dist_loss: 0.0268 - val_abs_vect_loss: -0.9897 - val_abs_vect_1_loss: -0.9900 - val_manh_dist_rmse: 0.1638 - val_manh_dist_mae: 0.1323
# Epoch 20/20
# 781/781 [==============================] - 325s 416ms/step - loss: -0.4819 - manh_dist_loss: 0.0255 - abs_vect_loss: -0.9893 - abs_vect_1_loss: -0.9895 - manh_dist_rmse: 0.1597 - manh_dist_mae: 0.1291 - val_loss: -0.4812 - val_manh_dist_loss: 0.0274 - val_abs_vect_loss: -0.9896 - val_abs_vect_1_loss: -0.9899 - val_manh_dist_rmse: 0.1654 - val_manh_dist_mae: 0.1329

# %% [markdown]
# # 3. Model Evaluation

# %%
model.layers
# Out:
# [<tensorflow.python.keras.engine.input_layer.InputLayer at 0x7fe680db1610>,
#  <tensorflow.python.keras.engine.input_layer.InputLayer at 0x7fe680db1b50>,
#  <tensorflow.python.keras.engine.sequential.Sequential at 0x7fe680e047d0>,
#  <deep_hashing_models.ManhDist at 0x7fe680db1d10>,
#  <deep_hashing_models.AbsVect at 0x7fe680e3e290>,
#  <deep_hashing_models.AbsVect at 0x7fe680d81990>]

# %% [markdown]
# ## 3.1. Loss functions

# %% [markdown]
# #### 3.1.1. MSE of $\mathcal{L}_{Baseline}$

# %%
plt.rcParams["figure.figsize"] = (8,5)
plt.plot(siamese_model.history['loss'], linewidth = 2)
plt.plot(siamese_model.history['val_loss'], linewidth = 2)
plt.title('Brodie (Baseline)', fontsize = 20)
plt.ylabel('MSE (Model)', fontsize = 12)
plt.xlabel('Epochs', fontsize = 12)
plt.ticklabel_format(style='', scilimits=(0,0))
plt.legend(['Train', 'Validation'], loc='upper right', fontsize=15)

# %% [markdown]
# #### 3.1.2. RMSE of Hash preserving loss

# %%
plt.rcParams["figure.figsize"] = (8,5)
plt.plot(siamese_model.history[model.layers[3].name + '_rmse'], linewidth = 2)
plt.plot(siamese_model.history['val_' + model.layers[3].name + '_rmse'], linewidth = 2)
plt.title('Brodie (Baseline)', fontsize = 20)
plt.ylabel('RMSE (Hash-preserving)', fontsize = 12)
plt.xlabel('Epochs', fontsize = 12)
plt.ticklabel_format(style='', scilimits=(0,0))
plt.legend(['Train', 'Validation'], loc='upper right', fontsize=15)

# %% [markdown]
# #### 3.1.3. MAE of Hash preserving loss

# %%
plt.rcParams["figure.figsize"] = (8,5)
plt.plot(siamese_model.history[model.layers[3].name + '_mae'], linewidth = 2)
plt.plot(siamese_model.history['val_' + model.layers[3].name + '_mae'], linewidth = 2)
plt.title('Brodie (Baseline)', fontsize = 20)
plt.ylabel('MAE (Hash-preserving)', fontsize = 12)
plt.xlabel('Epochs', fontsize = 12)
plt.ticklabel_format(style='', scilimits=(0,0))
plt.legend(['Train', 'Validation'], loc='upper right', fontsize=15)

# %% [markdown]
# ## 3.2. Model Predictions

# %%
predictions = predict(model, X_validation)

# %% [markdown]
# ### 3.2.1. Examples

# %%
np.around(predictions[0][:50],3)
# Out:
# array([0.11 , 0.114, 0.172, 0.206, 0.183, 0.356, 0.049, 0.484, 0.219,
#        0.219, 0.091, 0.186, 0.046, 0.207, 0.032, 0.113, 0.149, 0.178,
#        0.164, 0.022, 0.106, 0.218, 0.072, 0.148, 0.29 , 0.42 , 0.21 ,
#        0.213, 0.012, 0.109, 0.016, 0.229, 0.151, 0.011, 0.173, 0.132,
#        0.075, 0.078, 0.139, 0.014, 0.156, 0.054, 0.245, 0.041, 0.144,
#        0.024, 0.58 , 0.071, 0.236, 0.024], dtype=float32)

# %%
np.around(Y_validation[:50],3)
# Out:
# array([0.001, 0.   , 0.003, 0.107, 0.   , 0.   , 0.   , 0.275, 0.026,
#        0.   , 0.   , 0.038, 0.   , 0.032, 0.052, 0.029, 0.013, 0.01 ,
#        0.035, 0.   , 0.   , 0.   , 0.   , 0.   , 0.131, 0.127, 0.   ,
#        0.058, 0.   , 0.   , 0.   , 0.   , 0.023, 0.   , 0.   , 0.   ,
#        0.012, 0.   , 0.   , 0.   , 0.   , 0.   , 0.   , 0.   , 0.02 ,
#        0.   , 0.413, 0.   , 0.043, 0.   ])

# %% [markdown]
# ### 3.2.2. Spearman $\rho$ and Kendall $\tau$ correlation

# %%
plt.rcParams["figure.figsize"] = (4,4)
plt.scatter(Y_validation, predictions[0], alpha = 0.5, marker = 'x', c = '#227093')
plt.title('Brodie (Baseline)', fontsize = 16)
plt.xlabel("Brodie similarity values", fontsize = 12)
plt.ylabel("Collision probability", fontsize = 12)
plt.savefig('Results/Baseline/Brodie-correlation', bbox_inches='tight')
plt.show()

# %%
rho, p_value = spearman_rho(predictions, Y_validation)
rho
# Out:
# 0.6124297546192464

# %%
tau, p_value = kendall_tau(predictions, Y_validation)
tau
# Out:
# 0.4810851325462165

# %% [markdown]
# ## 3.3. Approximate Hamming Evaluation

# %%
output_layer = 0
model.layers[output_layer]

# %%
intermediate_model = intermediate_model_trained(shared_model, output_layer, True, input_tensor)

# %%
intermediate_model.save('Models/model-baseline.model')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: Models/model-deep-hash.model/assets

# %%
#intermediate_model = keras.models.load_model('Models/model-baseline.model')

# %% [markdown]
# ### 3.3.1. Example of a hash vector provided by the model (in the last epoch)

# %%
intermediate_model.predict(padding(X.iloc[[11]], max_length)['stack_1'])[0][:32]
# Out:
# array([ 0.7245932 ,  0.9996602 , -0.9993832 ,  0.7549039 ,  0.9995274 ,
#         0.77047384,  0.9996702 , -0.9996629 ,  0.9997126 , -0.9996899 ,
#        -0.99975115, -0.99945724, -0.99959505,  0.9996514 , -0.67393094,
#        -0.99964434,  0.99949145, -0.6642591 ,  0.9993908 , -0.99951166,
#         0.9995097 ,  0.9995427 ,  0.99944854,  0.6851193 , -0.6192661 ,
#        -0.7632596 ,  0.770912  , -0.99929976,  0.9989966 , -0.69326234,
#         0.9995188 , -0.99892634], dtype=float32)

# %% [markdown]
# ### 3.3.2. Average value of the absolute hash values

# %%
hash_vectors = intermediate_model.predict(pad_sequences(df_distinct_stacks['rankFrames'], padding = 'post', truncating = 'post', maxlen = max_length))

# %%
np.mean(np.abs(hash_vectors))
# Out:
# 0.72671366

# %% [markdown]
# ### 3.3.3. Ratio of binary values from hash vectors provided by the model

# %%
hash_vectors[(hash_vectors == 1) | (hash_vectors == -1)].size / hash_vectors.size
# Out:
# 0.0004912109375

# %% [markdown]
# ### 3.3.4. Comparison between approximate hamming and real hamming

# %%
df_hamming = compare_hamming(X_validation, intermediate_model, b, size_hash_vector)

# %%
plt.rcParams["figure.figsize"] = (4,4)
plt.scatter(predictions[0], df_hamming['hamming'], alpha = 0.5, marker = 'x', c = '#b33939')
plt.xlabel("Approximate Hamming Similariy", fontsize = 12)
plt.ylabel("Hamming Similarity", fontsize = 12)
plt.title('Brodie (Baseline)', fontsize = 16)
plt.savefig('Results/Baseline/Brodie-hamming-comparison', bbox_inches='tight')
plt.show()

# %% [markdown]
# # 4. Locality Sensitive Hashing

# %%
hash_vectors_hamming = convert_to_hamming(hash_vectors)

# %%
params = lsh_hyperparams(m)
'(K,L)'
params
# Out:
# [(1, 64), (2, 32), (4, 16), (8, 8), (16, 4), (32, 2), (64, 1)]

# %% [markdown]
# ## 4.1. Choose the best combination (L, K)

# %%
plt.rcParams["figure.figsize"] = [9, 5]
x = np.linspace(0, 1, 100)
for param in params:
    y = 1 - (1 - (x)**param[1])**param[0]
    plt.plot(x, y, label = 'L = %d, r = %d' %param)
plt.xlabel("similarity values", fontsize = 12)
plt.ylabel("hash probability in at least 1 bucket", fontsize = 12)
plt.title('Probability-similarity relation', fontsize = 18)
plt.legend()

# %%
df_probLSH = mean_prob_hashing_smallest_elt(n_stacks, params, hash_vectors_hamming, b, df_measures, 'Brodie', trace = False)

# %%
f, ax = plt.subplots(figsize=(6, 4))
ax = sns.boxplot(data = df_probLSH, palette="Set3")
plt.xlabel("Hyperparameters of LSH (L,K)", fontsize = 12)
plt.ylabel("Prob hashing smallest elt in buckets", fontsize = 12)
plt.title('Brodie (Baseline) [Relation Prob-Sim]', fontsize = 16)
plt.savefig('Results/Baseline/Brodie-Relation-Prob-Sim', bbox_inches='tight')
plt.show()

# %%
'Exemple, L = K = 8'
L, K = params[2]
L, K
# Out:
# (4, 16)

# %%
df_probLSH.mean()['(4, 16)']

# %%
df_probLSH.median()['(4, 16)']

# %% [markdown]
# ## 4.2. Build hash tables with binary hash vectors w.r.t $K$ and $L$

# %%
hash_tables = create_hash_tables(L, K, b, hash_vectors_hamming)

# %%
with open('Hash-Tables/hash_tables_baseline.pkl', 'wb') as f:
    pickle.dump(hash_tables, f)

# %% [markdown]
# ## 4.3. Search for approximate nearest neighbors (this procedure need to be explained in the paper)

# %%
'pointer to the stack trace'
index = random.randint(0,n_stacks)
index

# %%
set_near_duplicates = near_duplicates(L, K, b, index, hash_vectors_hamming, hash_tables)
set_near_duplicates

# %%
list_near_duplicate_pairs = near_duplicate_pairs(index, set_near_duplicates, n_stacks)
n_duplicate_pairs = len(list_near_duplicate_pairs)

# %%
near_duplicates_sim = df_measures['Brodie'][list_near_duplicate_pairs].sort_values(ascending = False)
near_duplicates_sim

# %%
set_real_nns, real_nns_sim = real_nns(index, df_measures, 'Brodie', n_stacks, n_duplicate_pairs)
set_real_nns

# %%
real_nns_sim[:n_duplicate_pairs]

# %% [markdown]
# ## 4.4. Metrics

# %% [markdown]
# ### 4.4.1. Ratio of finding the $k$ real nearest neighbor with the Least $L$ (Recal rate at $k$ first positions)

# %%
'All params'
k_first_positions = 1
recal_rate(n_stacks, params, hash_vectors_hamming, b, df_measures, k_first_positions, 'Brodie')
# Out:
# 0.757

# %%
'Best param'
k_first_positions = 1
recal_rate_one_param(n_stacks, params[2], hash_vectors_hamming, b, df_measures, k_first_positions, 'Brodie')

# %% [markdown]
# -----------------------------------------------------------------

# %%
'All params'
k_first_positions = 3
recal_rate(n_stacks, params, hash_vectors_hamming, b, df_measures, k_first_positions, 'Brodie')
# Out:
# 0.6896666666666669

# %%
'Best param'
k_first_positions = 3
recal_rate_one_param(n_stacks, params[2], hash_vectors_hamming, b, df_measures, k_first_positions, 'Brodie')

# %% [markdown]
# -----------------------------------------------------------------

# %%
'All params'
k_first_positions = 5
recal_rate(n_stacks, params, hash_vectors_hamming, b, df_measures, k_first_positions, 'Brodie')
# Out:
# 0.6842000000000009

# %%
'Best param'
k_first_positions = 5
recal_rate_one_param(n_stacks, params[2], hash_vectors_hamming, b, df_measures, k_first_positions, 'Brodie')

# %% [markdown]
# ### 4.4.2. Accuracy of finding the real nearest neighbors (Generalized MRR)

# %% [markdown]
# $ \frac{1}{|\mathcal{R}_i|} \sum_{s' \in \mathcal{R}_i} \frac{\text{rank}(s',\mathcal{R}_i)}{\text{rank}(s',NNs(s_i))} $

# %%
generalized_mrr(near_duplicates_sim, real_nns_sim)

# %%
df_knns = mean_generalized_mrr(n_stacks, params[2:4], hash_vectors_hamming, b, df_measures ,'Brodie', trace = False)
df_knns.mean(skipna = True, axis = 0)
# Out:
# (4, 16)    0.629269
# (8, 8)     0.614995
# dtype: float64

# %%
df_knns.mean(skipna = True, axis = 0)['(4, 16)']
